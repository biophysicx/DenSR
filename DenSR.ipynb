# %% [markdown]
# Input files for observed RNA spot coordinates and 3D cell mesh

# %%
obj_file = f"C1_volume.obj" # file containing 3D cell mesh
file_1 = f"C1_1a_xyz.txt" # file containing RNA spots for condition 1
file_2 = f"C1_1b_xyz.txt" # file containing RNA spots for condition 2
coloc_threshold = 1 # threshold for colocalization: center to center distance (in microns)
# Set working directory
import os
os.chdir("/Users/sudharsankannan/Library/CloudStorage/OneDrive-UW-Madison/Taylor/data")    # Set your working directory which contains the data files

# %% [markdown]
# Load required libraries

# %%
import numpy as np
import pandas as pd
from scipy.stats import gaussian_kde
import gc
import igl
from scipy.spatial.distance import cdist
import trimesh

# %% [markdown]
# Functions for spatial randomization and object-based colocalization analysis

# %%
# Function to extract RNA spot coordinates from a text file
def extract_rna_spots(file):
    rna_data = pd.read_csv(file, sep='\t')
    print(rna_data.columns)  # Inspect column names if needed
    # rna_spots = rna_data[['Position X', 'Position Y', 'Position Z']].values
    rna_spots = rna_data.iloc[:, :3].values
    rna_spots = np.round(rna_spots, 4)
    return rna_spots


# Function to retain only spots located within the 3D cell mesh
def filter_spots_inside_mesh(mesh, spots):  # Consider replacing mesh.contains with winding number for large datasets
    spots = spots[np.all(np.isfinite(spots), axis=1)]

    # Obtain the mesh bounding box
    min_bound, max_bound = mesh.bounds

    # Pre-filter spots to the bounding box to reduce containment calculations
    within_bounds = np.all((spots >= min_bound) & (spots <= max_bound), axis=1)
    spots_within_bounds = spots[within_bounds]

    # Retain spots inside the mesh volume
    inside = mesh.contains(spots_within_bounds)

    return spots_within_bounds[inside]


def colocper(spots1, spots2, threshold=0.5):
    """
    Calculate bidirectional object-based colocalization between two spot populations.

    Returns the percentage of spots in population 1 located within the specified
    center-to-center distance threshold of population 2, and vice versa.
    """
    distances = cdist(spots1, spots2)

    close_spots1 = np.any(distances <= threshold, axis=1)
    percentage_spots1 = np.mean(close_spots1) * 100

    close_spots2 = np.any(distances <= threshold, axis=0)
    percentage_spots2 = np.mean(close_spots2) * 100

    result_dict = {
        'coloc_1_with_2': percentage_spots1,
        'coloc_2_with_1': percentage_spots2
    }
    return result_dict


# UniSR: uniform spatial randomization within the 3D cell mesh
def generate_unisr_spots(mesh, desired_points):
    min_bound, max_bound = mesh.bounds
    points_inside_mesh = []

    while len(points_inside_mesh) < desired_points:
        num_points_to_generate = desired_points - len(points_inside_mesh)
        candidate_points = np.random.uniform(
            low=min_bound,
            high=max_bound,
            size=(num_points_to_generate, 3)
        )
        inside = mesh.contains(candidate_points)
        points_inside_mesh.extend(candidate_points[inside])

    points_inside_mesh = np.array(points_inside_mesh)
    return points_inside_mesh


# Backward-compatible alias for older code
_generate_random_spots = generate_unisr_spots
generate_random_spots = generate_unisr_spots


def calculate_max_density(rna_spots, mesh, resolution=1.0):
    min_bound, max_bound = mesh.bounds
    num_bins = np.ceil((max_bound - min_bound) / resolution).astype(int)
    density_grid = np.zeros(num_bins, dtype=int)

    shifted_spots = rna_spots - min_bound
    bin_indices = np.floor(shifted_spots / resolution).astype(int)

    for idx in bin_indices:
        if np.all(idx >= 0) and np.all(idx < num_bins):
            density_grid[tuple(idx)] += 1

    density_grid = density_grid / (resolution ** 3)
    max_density = np.max(density_grid)

    return max_density


def calculate_max_density_bbox(rna_spots, min_bound, max_bound, resolution=1.0):
    """
    Calculate the maximum local spot density within a 3D bounding box grid.

    Parameters:
        rna_spots (np.ndarray): Nx3 array of RNA spot coordinates.
        min_bound (np.ndarray): Minimum x, y, and z values of the bounding box.
        max_bound (np.ndarray): Maximum x, y, and z values of the bounding box.
        resolution (float): Grid resolution in microns.

    Returns:
        float: Maximum local density in spots per µm³.
    """
    num_bins = np.ceil((max_bound - min_bound) / resolution).astype(int)
    density_grid = np.zeros(num_bins, dtype=int)

    shifted_spots = rna_spots - min_bound
    bin_indices = np.floor(shifted_spots / resolution).astype(int)

    for idx in bin_indices:
        if np.all(idx >= 0) and np.all(idx < num_bins):
            density_grid[tuple(idx)] += 1

    density_grid = density_grid / (resolution ** 3)
    return np.max(density_grid)


# DenSR: density-aware spatial randomization using KDE-weighted sampling within the 3D cell mesh
def generate_densr_spots(rna_spots, mesh):
    kde_model = gaussian_kde(rna_spots.T)

    min_bound, max_bound = mesh.bounds
    bbox_volume = np.prod(max_bound - min_bound)

    spots_per_cubic_um = calculate_max_density(rna_spots, mesh)
    desired_points = int(bbox_volume * spots_per_cubic_um / 2)

    candidate_points = np.random.uniform(
        low=min_bound,
        high=max_bound,
        size=(desired_points, 3)
    )

    V = np.array(mesh.vertices)
    F = np.array(mesh.faces)

    # Use winding number to retain candidate points inside the mesh volume
    W = igl.fast_winding_number_for_meshes(V, F, candidate_points)
    inside_mask = W >= 0.5
    points_inside_mesh = np.array(candidate_points[inside_mask])

    # Evaluate KDE over candidate positions and use the normalized density as sampling weights
    kde_eval = kde_model(points_inside_mesh.T)
    probabilities = kde_eval / np.sum(kde_eval)

    sampled_indices = np.random.choice(
        len(points_inside_mesh),
        len(rna_spots),
        replace=False,
        p=probabilities
    )
    densr_spots = points_inside_mesh[sampled_indices]

    return densr_spots


# Backward-compatible alias for older code
generate_kde_spots = generate_densr_spots

# %% [markdown]
# Colocalization analysis using observed data, UniSR, and DenSR

# %%
rna_spots_1 = extract_rna_spots(file_1)
rna_spots_2 = extract_rna_spots(file_2)
mesh = trimesh.load_mesh(obj_file)

# Observed object-based colocalization
observed_coloc = colocper(rna_spots_1, rna_spots_2, threshold=coloc_threshold)

# UniSR: uniform spatial randomization within the 3D cell mesh
unisr_spots_1 = generate_unisr_spots(mesh, desired_points=len(rna_spots_1))
unisr_spots_2 = generate_unisr_spots(mesh, desired_points=len(rna_spots_2))
unisr_coloc = colocper(unisr_spots_1, unisr_spots_2, threshold=coloc_threshold)

# DenSR: density-aware spatial randomization using KDE-weighted sampling within the 3D cell mesh
densr_spots_1 = generate_densr_spots(rna_spots_1, mesh)
densr_spots_2 = generate_densr_spots(rna_spots_2, mesh)
densr_coloc = colocper(densr_spots_1, densr_spots_2, threshold=coloc_threshold)

gc.collect()

# === Combine results into publication-ready summary tables ===
coloc_1_with_2_table = pd.DataFrame([{
    "Observed": observed_coloc["coloc_1_with_2"],
    "UniSR": unisr_coloc["coloc_1_with_2"],
    "DenSR": densr_coloc["coloc_1_with_2"],
}])

coloc_2_with_1_table = pd.DataFrame([{
    "Observed": observed_coloc["coloc_2_with_1"],
    "UniSR": unisr_coloc["coloc_2_with_1"],
    "DenSR": densr_coloc["coloc_2_with_1"],
}])

# === Output ===
print("\nPercentage of population 1 colocalized with population 2:\n", coloc_1_with_2_table)
print("\nPercentage of population 2 colocalized with population 1:\n", coloc_2_with_1_table)
# Out:
# Index(['Position.X', 'Position.Y', 'Position.Z'], dtype='object')
# Index(['Position.X', 'Position.Y', 'Position.Z'], dtype='object')
#
# Percentage of population 1 colocalized with population 2:
#      Observed  UniSR     DenSR
# 0  12.280702    0.0  3.508772
#
# Percentage of population 2 colocalized with population 1:
#      Observed  UniSR      DenSR
# 0  31.578947    0.0  10.526316
